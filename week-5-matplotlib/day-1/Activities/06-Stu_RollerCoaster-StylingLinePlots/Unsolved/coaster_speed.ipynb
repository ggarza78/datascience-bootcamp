# %%
# %matplotlib notebook

# %%
# Import Dependencies
import matplotlib.pyplot as plt
import numpy as np

# %%
danger_drop_speeds = np.array([9, 8, 90, 85, 80, 70, 70, 65, 55, 60, 70, 65, 50])
railgun_speeds = np.array([75, 70, 60, 65, 60, 45, 55, 50, 40, 40, 35, 35, 30])
time = np.arange(0, 121, 10)

# %%
# Plot the charts and apply some styling
danger_drop = plt.plot(time, danger_drop_speeds, color="red", label="Danger drop")
railgun = plt.plot(time, railgun_speeds, color="blue", label="Railgun")

# Add labels to X and Y axes :: Add title
plt.xlabel("Coaster runtime")
plt.ylabel("Speed (mph)")
plt.title("Coaster speed over time")

# Set the limits for the X and Y axes
plt.xlim(0, 120)
plt.ylim(0, 95)

# Create a legend for the chart
plt.legend(loc="best")

# Add in a grid for the chart
plt.grid()

# plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.4833333333333">
